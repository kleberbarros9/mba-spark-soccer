# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, year

# Função para criar sessão Spark
def create_spark_session() -> SparkSession:
    spark = (
        SparkSession.builder
        .appName("ETL Silver - Match")
        .enableHiveSupport()
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
        .config("spark.hadoop.fs.s3minio.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
        .getOrCreate()
    )
    return spark

# Inicializa Spark
spark = create_spark_session()

# Configurações MinIO
minio_delta_options = {
    "fs.s3a.access.key": "admin",
    "fs.s3a.secret.key": "senhasegura",
    "fs.s3a.endpoint": "http://minio:9000",
    "fs.s3a.path.style.access": "true",
    "fs.s3a.connection.ssl.enabled": "false"
}

# Caminho Bronze
bronze_match_path = "s3a://bucket-bronze-zone/soccer/Match"

# Leitura do Delta Lake Bronze
df_bronze = (
    spark.read
    .format("delta")
    .options(**minio_delta_options)
    .load(bronze_match_path)
)

# Transformações
df_silver = (
    df_bronze
    # Remover colunas _airbyte_*
    .drop(*[c for c in df_bronze.columns if c.startswith("_airbyte")])
    # Converter 'date' de string para DateType com apenas data (YYYY-MM-DD)
    .withColumn("match_date", to_date(col("date")))
    .drop("date")
    # Criar coluna 'year' para facilitar análises e particionamentos
    .withColumn("year", year(col("match_date")))
)

# Validação: verificar dados transformados
print(f"Quantidade de registros após transformação: {df_silver.count()}")
df_silver.show(5)
df_silver.printSchema()

# Caminho Silver
silver_match_path = "s3a://bucket-silver-zone/soccer/Match"

# Escrita no Delta Lake Silver com particionamento por 'year'
(
    df_silver
    # Remover registros com valores nulos (Dropna na etapa de transformação dava overflow de memória)
    .dropna()
    .write
    .format("delta")
    .mode("overwrite")
    .partitionBy("year")  # Particionamento por 'year'
    .option("overwriteSchema", "true")
    .options(**minio_delta_options)
    .save(silver_match_path)
)

print("Tabela 'Match' transformada, particionada por 'year' e gravada com sucesso na camada Silver no MinIO!")

# Finaliza Spark
spark.stop()
# Out:
# Quantidade de registros após transformação: 25979
# +---+----+----+----+----+----+----+----+----+----+---+---+----+----+---+----+----+----+----+----+---+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+------+---------+------+-------+---------+----------+----------+----------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+--------------------+--------------------+----------+----+
# | id| BSA| BSD| BSH| BWA| BWD| BWH| GBA| GBD| GBH|IWA|IWD| IWH| LBA|LBD| LBH| PSA| PSD| PSH| SJA|SJD| SJH| VCA| VCD| VCH| WHA| WHD| WHH|card|goal|B365A|B365D|B365H|cross|stage|corner|   season|shoton|shotoff|league_id|country_id|foulcommit|possession|match_api_id|away_player_1|away_player_2|away_player_3|away_player_4|away_player_5|away_player_6|away_player_7|away_player_8|away_player_9|home_player_1|home_player_2|home_player_3|home_player_4|home_player_5|home_player_6|home_player_7|home_player_8|home_player_9|away_player_10|away_player_11|away_player_X1|away_player_X2|away_player_X3|away_player_X4|away_player_X5|away_player_X6|away_player_X7|away_player_X8|away_player_X9|away_player_Y1|away_player_Y2|away_player_Y3|away_player_Y4|away_player_Y5|away_player_Y6|away_player_Y7|away_
|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|             0|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|             5|           null|           null|           null|           null|           null|           null|           null|           null|            9998|            9991|2025-05-21 14:25:...|s3a://dev-lab-02-...|2008-08-17|2008|
# |  5|1.67| 3.3|4.75| 1.6| 3.5| 5.0|1.65| 3.5| 4.5|1.7|3.3| 4.0|1.72|3.4| 4.0|null|null|null|1.73|3.5| 4.5|1.65| 3.4| 4.5| 1.7| 3.4| 4.2|null|null| 1.65|  3.5|  5.0| null|    1|  null|2008/2009|  null|   null|        1|         1|      null|      null|      492477|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|         null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|             3|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|          null|             1|           null|           null|           null|           null|           null|           null|           null|           null|            9985|            7947|2025-05-21 14:25:...|s3a://dev-lab-02-...|2008-08-16|2008|
# +---+----+----+----+----+----+----+----+----+----+---+---+----+----+---+----+----+----+----+----+---+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+------+---------+------+-------+---------+----------+----------+----------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+--------------------+--------------------+----------+----+
# only showing top 5 rows
#
# root
#  |-- id: long (nullable = true)
#  |-- BSA: double (nullable = true)
#  |-- BSD: double (nullable = true)
#  |-- BSH: double (nullable = true)
#  |-- BWA: double (nullable = true)
#  |-- BWD: double (nullable = true)
#  |-- BWH: double (nullable = true)
#  |-- GBA: double (nullable = true)
#  |-- GBD: double (nullable = true)
#  |-- GBH: double (nullable = true)
#  |-- IWA: double (nullable = true)
#  |-- IWD: double (nullable = true)
#  |-- IWH: double (nullable = true)
#  |-- LBA: double (nullable = true)
#  |-- LBD: double (nullable = true)
#  |-- LBH: double (nullable = true)
#  |-- PSA: double (nullable = true)
#  |-- PSD: double (nullable = true)
#  |-- PSH: double (nullable = true)
#  |-- SJA: double (nullable = true)
#  |-- SJD: double (nullable = true)
#  |-- SJH: double (nullable = true)
#  |-- VCA: double (nullable = true)
#  |-- VCD: double (nullable = true)
#  |-- VCH: double (nullable = true)
#  |-- WHA: double (nullable = true)
#  |-- WHD: double (nullable = true)
#  |-- WHH: double (nullable = true)
#  |-- card: string (nullable = true)
#  |-- goal: string (nullable = true)
#  |-- B365A: double (nullable = true)
#  |-- B365D: double (nullable = true)
#  |-- B365H: double (nullable = true)
#  |-- cross: string (nullable = true)
#  |-- stage: long (nullable = true)
#  |-- corner: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- shoton: string (nullable = true)
#  |-- shotoff: string (nullable = true)
#  |-- league_id: long (nullable = true)
#  |-- country_id: long (nullable = true)
#  |-- foulcommit: string (nullable = true)
#  |-- possession: string (nullable = true)
#  |-- match_api_id: long (nullable = true)
#  |-- away_player_1: long (nullable = true)
#  |-- away_player_2: long (nullable = true)
#  |-- away_player_3: long (nullable = true)
#  |-- away_player_4: long (nullable = true)
#  |-- away_player_5: long (nullable = true)
#  |-- away_player_6: long (nullable = true)
#  |-- away_player_7: long (nullable = true)
#  |-- away_player_8: long (nullable = true)
#  |-- away_player_9: long (nullable = true)
#  |-- home_player_1: long (nullable = true)
#  |-- home_player_2: long (nullable = true)
#  |-- home_player_3: long (nullable = true)
#  |-- home_player_4: long (nullable = true)
#  |-- home_player_5: long (nullable = true)
#  |-- home_player_6: long (nullable = true)
#  |-- home_player_7: long (nullable = true)
#  |-- home_player_8: long (nullable = true)
#  |-- home_player_9: long (nullable = true)
#  |-- away_player_10: long (nullable = true)
#  |-- away_player_11: long (nullable = true)
#  |-- away_player_X1: long (nullable = true)
#  |-- away_player_X2: long (nullable = true)
#  |-- away_player_X3: long (nullable = true)
#  |-- away_player_X4: long (nullable = true)
#  |-- away_player_X5: long (nullable = true)
#  |-- away_player_X6: long (nullable = true)
#  |-- away_player_X7: long (nullable = true)
#  |-- away_player_X8: long (nullable = true)
#  |-- away_player_X9: long (nullable = true)
#  |-- away_player_Y1: long (nullable = true)
#  |-- away_player_Y2: long (nullable = true)
#  |-- away_player_Y3: long (nullable = true)
#  |-- away_player_Y4: long (nullable = true)
#  |-- away_player_Y5: long (nullable = true)
#  |-- away_player_Y6: long (nullable = true)
#  |-- away_player_Y7: long (nullable = true)
#  |-- away_player_Y8: long (nullable = true)
#  |-- away_player_Y9: long (nullable = true)
#  |-- away_team_goal: long (nullable = true)
#  |-- home_player_10: long (nullable = true)
#  |-- home_player_11: long (nullable = true)
#  |-- home_player_X1: long (nullable = true)
#  |-- home_player_X2: long (nullable = true)
#  |-- home_player_X3: long (nullable = true)
#  |-- home_player_X4: long (nullable = true)
#  |-- home_player_X5: long (nullable = true)
#  |-- home_player_X6: long (nullable = true)
#  |-- home_player_X7: long (nullable = true)
#  |-- home_player_X8: long (nullable = true)
#  |-- home_player_X9: long (nullable = true)
#  |-- home_player_Y1: long (nullable = true)
#  |-- home_player_Y2: long (nullable = true)
#  |-- home_player_Y3: long (nullable = true)
#  |-- home_player_Y4: long (nullable = true)
#  |-- home_player_Y5: long (nullable = true)
#  |-- home_player_Y6: long (nullable = true)
#  |-- home_player_Y7: long (nullable = true)
#  |-- home_player_Y8: long (nullable = true)
#  |-- home_player_Y9: long (nullable = true)
#  |-- home_team_goal: long (nullable = true)
#  |-- away_player_X10: long (nullable = true)
#  |-- away_player_X11: long (nullable = true)
#  |-- away_player_Y10: long (nullable = true)
#  |-- away_player_Y11: long (nullable = true)
#  |-- home_player_X10: long (nullable = true)
#  |-- home_player_X11: long (nullable = true)
#  |-- home_player_Y10: long (nullable = true)
#  |-- home_player_Y11: long (nullable = true)
#  |-- away_team_api_id: long (nullable = true)
#  |-- home_team_api_id: long (nullable = true)
#  |-- _ingest_timestamp: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#  |-- match_date: date (nullable = true)
#  |-- year: integer (nullable = true)
#
# Tabela 'Match' transformada, particionada por 'year' e gravada com sucesso na camada Silver no MinIO!
